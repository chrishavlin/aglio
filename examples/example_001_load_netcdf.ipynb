# %%
import aglio

filename = "IRIS/GYPSUM_percent.nc"

ds = aglio.open_dataset(filename)
ds.aglio.surface_gpd.plot()
# Out:
# aglio : [INFO ] 2023-06-28 15:53:07,118:  no data, using supplied lat_y and lon_x.
# <Axes: >

# %%
import aglio
from aglio.seismology import datasets as ysd

filename = "IRIS/wUS-SH-2010_percent.nc"
refmodel = "IRIS/refModels/AK135F_AVG.csv"

refAK = ysd.load_1d_csv_ref_collection(refmodel, "depth_km")
ds = aglio.open_dataset(filename)
abs_vs = ds.aglio.get_absolute(refAK, "dvs", "Vs_kms")
